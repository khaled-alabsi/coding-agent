# %%
from open_coder_agent import run

# %%
# !pip install opencode-ai
# Out:
# zsh:1: /Users/Khaled.Alabsi/projects/coding_agent/venv/bin/pip: bad interpreter: /Users/Khaled.Alabsi/projects/test-cli-agents/venv/bin/python: no such file or directory
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencode-ai
#   Downloading opencode_ai-0.1.0a36-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (2.9.2)
# Requirement already satisfied: sniffio in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from opencode-ai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from anyio<5,>=3.5.0->opencode-ai) (3.10)
# Requirement already satisfied: certifi in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from httpx<1,>=0.23.0->opencode-ai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from httpx<1,>=0.23.0->opencode-ai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->opencode-ai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from pydantic<3,>=1.9.0->opencode-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/Khaled.Alabsi/Library/Python/3.12/lib/python/site-packages (from pydantic<3,>=1.9.0->opencode-ai) (2.23.4)
# Downloading opencode_ai-0.1.0a36-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.2/110.2 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: opencode-ai
# Successfully installed opencode-ai-0.1.0a36
#
# [notice] A new release of pip is available: 24.1.2 -> 25.3
# [notice] To update, run: pip3.12 install --upgrade pip

# %%
# Example usage patterns:

# 1. Continue from last session (default) - auto-saves every 30 seconds
# run()

# 2. Start fresh with timeout and custom auto-save interval
# run(continue_from_history=False, timeout_seconds=600, auto_save_interval=20)

# 3. Continue with a 10-minute timeout
# run(timeout_seconds=600)

# 4. View what the agent did previously
# from interpreter_agent import view_history
# view_history()

# 5. Continue with specific instructions and timeout
# from interpreter_agent import continue_conversation
# continue_conversation("Add user authentication to the API", timeout_seconds=300)

# 6. Force save current state (useful if running in interactive mode)
# from interpreter_agent import force_save
# force_save()

# 7. Clear all history and start over
# from interpreter_agent import clear_history
# clear_history()

# Uncomment the one you want to use:
# Using 5-minute timeout to prevent getting stuck
run(timeout_seconds=300, auto_save_interval=30)  # Auto-saves every 30 seconds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/coding_agent/open_coder/open_coder_agent.py:8, in _get_client(base_url)
#       7 try:
# ----> 8     from opencode_ai import Opencode  # type: ignore
#       9 except ModuleNotFoundError as e:
#
# ModuleNotFoundError: No module named 'opencode_ai'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 30
#       1 # Example usage patterns:
#       2
#       3 # 1. Continue from last session (default) - auto-saves every 30 seconds
#    (...)     28 # Uncomment the one you want to use:
#      29 # Using 5-minute timeout to prevent getting stuck
# ---> 30 run(timeout_seconds=300, auto_save_interval=30)  # Auto-saves every 30 seconds
#
# File ~/projects/coding_agent/open_coder/open_coder_agent.py:24, in run(base_url, title, **_kwargs)
#      23 def run(*, base_url: Optional[str] = None, title: Optional[str] = None, **_kwargs) -> None:
# ---> 24     client = _get_client(base_url)
#      26     session = client.session.create(
#      27         body={"title": title or "Qwen3 Coder 30B – OpenCode demo"}
#      28     )
#      29     print("Session ID:", session.id)
#
# File ~/projects/coding_agent/open_coder/open_coder_agent.py:10, in _get_client(base_url)
#       8     from opencode_ai import Opencode  # type: ignore
#       9 except ModuleNotFoundError as e:
# ---> 10     raise ModuleNotFoundError(
#      11         "Missing dependency 'opencode_ai'. Install with `pip install opencode-ai` "
#      12         "and ensure your OpenCode server is running."
#      13     ) from e
#      15 resolved_base = (
#      16     base_url
#      17     or os.environ.get("OPENCODE_BASE_URL")
#      18     or "http://127.0.0.1:4096"
#      19 )
#      20 return Opencode(base_url=resolved_base)
#
# ModuleNotFoundError: Missing dependency 'opencode_ai'. Install with `pip install opencode-ai` and ensure your OpenCode server is running.
